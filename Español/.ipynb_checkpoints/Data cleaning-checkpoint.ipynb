# %% [markdown]
# # Proyecto limpieza de datos

# %% [markdown]
# ## Objetivos
#
#
# - Obtener los datos limpios donde todas las personas sean residentes de USA
# - Analizar datos para saber el salario promedio anual en USA
# - Analizar datos para saber cuales son las industrias que pagan mas en promedio
# - Analizar datos para saber en promedio que estados de USA pagan mas
# - Analizar datos para saber cuales son los trabajos que otorgan mejores bonos

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Importando librerias necesarias para la limpieza de datos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Base de datos a limpiar

# %%
df = pd.read_csv("Data\Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv", index_col='Timestamp', parse_dates=['Timestamp'])
df.head(5)
# Out:
#                     How old are you?  What industry do you work in?  \
# Timestamp
# 2021-04-27 11:02:10            25-34   Education (Higher Education)
# 2021-04-27 11:02:22            25-34              Computing or Tech
# 2021-04-27 11:02:38            25-34  Accounting, Banking & Finance
# 2021-04-27 11:02:41            25-34                     Nonprofits
# 2021-04-27 11:02:42            25-34  Accounting, Banking & Finance
#
#                                                     Job title  \
# Timestamp
# 2021-04-27 11:02:10        Research and Instruction Librarian
# 2021-04-27 11:02:22  Change & Internal Communications Manager
# 2021-04-27 11:02:38                      Marketing Specialist
# 2021-04-27 11:02:41                           Program Manager
# 2021-04-27 11:02:42                        Accounting Manager
#
#                     If your job title needs additional context, please clarify here:  \
# Timestamp
# 2021-04-27 11:02:10                                                NaN
# 2021-04-27 11:02:22                                                NaN
# 2021-04-27 11:02:38                                                NaN
# 2021-04-27 11:02:41                                                NaN
# 2021-04-27 11:02:42                                                NaN
#
#                     What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# Timestamp
# 2021-04-27 11:02:10                                             55,000
# 2021-04-27 11:02:22                                             54,600
# 2021-04-27 11:02:38                                             34,000
# 2021-04-27 11:02:41                                             62,000
# 2021-04-27 11:02:42                                             60,000
#
#                      How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# Timestamp
# 2021-04-27 11:02:10                                                0.0
# 2021-04-27 11:02:22                                             4000.0
# 2021-04-27 11:02:38                                                NaN
# 2021-04-27 11:02:41                                             3000.0
# 2021-04-27 11:02:42                                             7000.0
#
#                     Please indicate the currency  \
# Timestamp
# 2021-04-27 11:02:10                          USD
# 2021-04-27 11:02:22                          GBP
# 2021-04-27 11:02:38                          USD
# 2021-04-27 11:02:41                          USD
# 2021-04-27 11:02:42                          USD
#
#                     If "Other," please indicate the currency here:   \
# Timestamp
# 2021-04-27 11:02:10                                             NaN
# 2021-04-27 11:02:22                                             NaN
# 2021-04-27 11:02:38                                             NaN
# 2021-04-27 11:02:41                                             NaN
# 2021-04-27 11:02:42                                             NaN
#
#                     If your income needs additional context, please provide it here:  \
# Timestamp
# 2021-04-27 11:02:10                                                NaN
# 2021-04-27 11:02:22                                                NaN
# 2021-04-27 11:02:38                                                NaN
# 2021-04-27 11:02:41                                                NaN
# 2021-04-27 11:02:42                                                NaN
#
#                     What country do you work in?  \
# Timestamp
# 2021-04-27 11:02:10                United States
# 2021-04-27 11:02:22               United Kingdom
# 2021-04-27 11:02:38                           US
# 2021-04-27 11:02:41                          USA
# 2021-04-27 11:02:42                           US
df.dtypes
# Out:
# edad               object
# industria          object
# trabajo            object
# salario anual      object
# bonos               int32
# moneda             object
# pais de trabajo    object
# estado             object
# dtype: object

# %% [markdown]
# Eliminando las comas de los dijitos y convirtiendo la columna en numeros enteros

# %%
df['salario anual'] = df['salario anual'].str.replace(",", "").astype(int)
df.dtypes
# Out:
# edad               object
# industria          object
# trabajo            object
# salario anual       int32
# bonos               int32
# moneda             object
# pais de trabajo    object
# estado             object
# dtype: object

# %% [markdown]
# Eliminando los espacios de las cadenas de texto para facilitar la busqueda de paises

# %%
df['pais de trabajo'] = df['pais de trabajo'].str.replace(" ", "")
df.head(5)
# Out:
#                       edad                      industria  \
# Timestamp
# 2021-04-27 11:02:10  25-34   Education (Higher Education)
# 2021-04-27 11:02:22  25-34              Computing or Tech
# 2021-04-27 11:02:38  25-34  Accounting, Banking & Finance
# 2021-04-27 11:02:41  25-34                     Nonprofits
# 2021-04-27 11:02:42  25-34  Accounting, Banking & Finance
#
#                                                       trabajo  salario anual  \
# Timestamp
# 2021-04-27 11:02:10        Research and Instruction Librarian          55000
# 2021-04-27 11:02:22  Change & Internal Communications Manager          54600
# 2021-04-27 11:02:38                      Marketing Specialist          34000
# 2021-04-27 11:02:41                           Program Manager          62000
# 2021-04-27 11:02:42                        Accounting Manager          60000
#
#                      bonos moneda pais de trabajo          estado
# Timestamp
# 2021-04-27 11:02:10      0    USD    UnitedStates   Massachusetts
# 2021-04-27 11:02:22   4000    GBP   UnitedKingdom             NaN
# 2021-04-27 11:02:38      0    USD              US       Tennessee
# 2021-04-27 11:02:41   3000    USD             USA       Wisconsin
# 2021-04-27 11:02:42   7000    USD              US  South Carolina

# %% [markdown]
# Usando regex para encontrar todas aquellas personas que usaron distintos tipos de nomenclatura para el pais USA
#
# ejemplo (US, United states, U.S.A )
#
# y reemplazandolo por la palabra USA para asi agrupar todas las personas que trabajan en estados unidos en una nomenclatura para todos

# %%
df['pais de trabajo'] = df['pais de trabajo'].str.replace("^U\.[^kKaA].+", "USA", regex=True)
df['pais de trabajo'] = df['pais de trabajo'].str.replace("^Un....[^kKaA].+", "USA", regex=True)
df['pais de trabajo'] = df['pais de trabajo'].str.replace("^U[sS]", "USA", regex=True)
df['pais de trabajo'] = df['pais de trabajo'].str.replace("^TheU.+", "USA", regex=True)
df['pais de trabajo'] = df['pais de trabajo'].str.replace("^USA.+", "USA", regex=True)

# %% [markdown]
# Obteniendo los datos limpios y listos para analizar y sacar informacion que ayude a la toma de decisiones

# %%
clean_data = df[df['pais de trabajo'].str.contains("^USA")]
clean_data.head(5)
# Out:
#                       edad                      industria  \
# Timestamp
# 2021-04-27 11:02:10  25-34   Education (Higher Education)
# 2021-04-27 11:02:38  25-34  Accounting, Banking & Finance
# 2021-04-27 11:02:41  25-34                     Nonprofits
# 2021-04-27 11:02:42  25-34  Accounting, Banking & Finance
# 2021-04-27 11:02:46  25-34   Education (Higher Education)
#
#                                                 trabajo  salario anual  bonos  \
# Timestamp
# 2021-04-27 11:02:10  Research and Instruction Librarian          55000      0
# 2021-04-27 11:02:38                Marketing Specialist          34000      0
# 2021-04-27 11:02:41                     Program Manager          62000   3000
# 2021-04-27 11:02:42                  Accounting Manager          60000   7000
# 2021-04-27 11:02:46      Scholarly Publishing Librarian          62000      0
#
#                     moneda pais de trabajo          estado
# Timestamp
# 2021-04-27 11:02:10    USD             USA   Massachusetts
# 2021-04-27 11:02:38    USD             USA       Tennessee
# 2021-04-27 11:02:41    USD             USA       Wisconsin
# 2021-04-27 11:02:42    USD             USA  South Carolina
# 2021-04-27 11:02:46    USD             USA   New Hampshire

# %% [markdown]
# # Analizando datos

# %% [markdown]
# Obteniendo el salario promedio anual en USA

# %%
promedio_salario_anual_USA = clean_data.groupby('pais de trabajo')['salario anual'].mean().tolist()    
promedio_salario_anual_USA = '${:,.2f}'.format(promedio_salario_anual_USA[0])
print(f'El salario promedio anual en los estados unidos segun los datos dados es de {promedio_salario_anual_USA}')
# Out:
# El salario promedio anual en los estados unidos segun los datos dados es de $92,139.87

# %% [markdown]
# Obteniendo las industrias que pagan mas en promedio

# %%
industrias_mejor_pagadas = clean_data.groupby('industria')['salario anual'].mean().reset_index().sort_values(by='salario anual', ascending=False).head(5)
industrias_mejor_pagadas['salario anual'] = industrias_mejor_pagadas['salario anual'].map('${:,.2f}'.format)
industrias_mejor_pagadas.columns = ['Industrias', 'Salario Promedio Anual']
industrias_mejor_pagadas
# Out:
#                                             Industrias Salario Promedio Anual
# 171          Commercial Building Material Distribution            $400,000.00
# 843                                             Sports            $300,000.00
# 210                                 Corporate Training            $280,000.00
# 283  Energy (oil & gas & associated products, renew...            $253,300.00
# 644                       Pharmaceutical/biotechnology            $227,500.00

# %% [markdown]
# Obteniendo los estados de USA que pagan mas en promedio

# %%
estados_mejor_pagan = clean_data.groupby('estado')['salario anual'].mean().reset_index().sort_values(by='salario anual', ascending=False).head(5)
estados_mejor_pagan['salario anual'] = estados_mejor_pagan['salario anual'].map('${:,.2f}'.format)
estados_mejor_pagan.columns = ['Estados', 'Salario Promedio Anual']
estados_mejor_pagan
# Out:
#                         Estados Salario Promedio Anual
# 85  Michigan, Texas, Washington            $340,000.00
# 62                Indiana, Ohio            $245,000.00
# 36             Colorado, Nevada            $190,000.00
# 32            California, Texas            $185,000.00
# 26          California, Montana            $185,000.00

# %% [markdown]
# Obteniendo las industrias que otorgan mejores bonos

# %%
trabajos_mejores_bonos = clean_data.groupby('trabajo')['bonos'].mean().reset_index().sort_values(by='bonos', ascending=False).head(5)
trabajos_mejores_bonos['bonos'] = trabajos_mejores_bonos['bonos'].map('${:,.2f}'.format)
trabajos_mejores_bonos.columns = ['Trabajo', 'Bonos']
trabajos_mejores_bonos
# Out:
#                                Trabajo          Bonos
# 8678  Senior Business Systems Analyst   $1,000,000.00
# 9604    Senior staff software engineer  $1,000,000.00
# 5960          Manager of Data Science     $780,000.00
# 4773      Head of Software Engineering    $600,000.00
# 9825                Software architect    $500,000.00
